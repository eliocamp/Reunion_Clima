# %%
#codigo para descargar las figuras y armar la presentacion para la reunion mensual de monitoreo climatico

#pendiente: a partir del mes en el que se genera: automatizar nombres de archivos y path de busqueda de imagenes
#comunicacion con latex
#obtener fechas de pronos para pasarlas como argumentos a latex
#tomar de carpetas previas los archivos eps para trabajar en latex
#gestionar con el SMN un ftp de donde tomar las imagenes
#descargar imagenes de WMO
#descargar imagenes de SMN

#unificar nombre de archivos opcion: fuente_trimestreanio_var  ej: NMME_SON16_temp NMME_SON16_pcp

# %%
# Indicar Mes y Anio en el cual se va a trabajar
# MES 1(ENERO) 12 (DICIEMBRE)

MES = 11
ANIO = 2016
anio_c = 16
month = 'nov'
#trimestre1 = 'SON'
trimestre1 = 'DJF'

# %%
# Bajar imagenes de www.esrl.noaa.gov (reanalisis NCEP) 
#Zg200 hPa

#Trimestral
# Hay que definir que meses bajar y sobre que anios (hay que tener cuidado con los meses mas chicos)
#Enero=0 Diciembre=11

if MES>=4:
    mes_I=MES-4
    mes_F=MES-2
    anio_I=ANIO
    anio_F=ANIO
elif MES>=2:
    mes_I=MES-4+12
    mes_F=MES-2
    anio_I=ANIO-1
    anio_F=ANIO
elif MES==1:
    mes_I=MES-4+12
    mes_F=MES-2+12
    anio_I=ANIO-1
    anio_F=ANIO-1
    
print(mes_I)
print(mes_F)
print(anio_I)
print(anio_F)

import urllib.request
from bs4 import BeautifulSoup

url = 'http://www.esrl.noaa.gov/psd/cgi-bin/data/composites/comp.pl?var=Geopotential+Height&level=200mb&mon1='+str(mes_I)+'&mon2='+str(mes_F)+'&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&ipos[1]='+str(anio_I)+'&ipos[2]='+str(anio_F)+'&ineg[1]=&ineg[2]=&timefile0=&tstype=0&timefile1=&value=&typeval=1&compval=1&lag=0&labelc=Color&labels=Shaded&type=2&scale=100&labelcon=1&switch=0&cint=15&lowr=-90&highr=90&proj=ALL&xlat1=0&xlat2=90&xlon1=0&xlon2=360&custproj=Cylindrical+Equidistant&level1=1000mb&level2=10mb&Submit=Create+Plot'
response = urllib.request.urlopen(url)
data = response.read()      # a `bytes` object

soup = BeautifulSoup(data,'html.parser') #como es un xml, beautifull tiene un modulo de eso
link = soup.findAll('img')[-1]['src']

urllib.request.urlretrieve('http://www.esrl.noaa.gov'+link, "../Figuras/"+str(ANIO)+"/"+str(MES)+"/NCEP_zg200_Est.png")

#Mensual

url = 'http://www.esrl.noaa.gov/psd/cgi-bin/data/composites/comp.pl?var=Geopotential+Height&level=200mb&mon1='+str(mes_F)+'&mon2='+str(mes_F)+'&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&iy=&ipos[1]='+str(anio_I)+'&ipos[2]='+str(anio_F)+'&ineg[1]=&ineg[2]=&timefile0=&tstype=0&timefile1=&value=&typeval=1&compval=1&lag=0&labelc=Color&labels=Shaded&type=2&scale=100&labelcon=1&switch=0&cint=15&lowr=-90&highr=90&proj=ALL&xlat1=0&xlat2=90&xlon1=0&xlon2=360&custproj=Cylindrical+Equidistant&level1=1000mb&level2=10mb&Submit=Create+Plot'
response = urllib.request.urlopen(url)
data = response.read()      # a `bytes` object

soup = BeautifulSoup(data,'html.parser') #como es un xml, beautifull tiene un modulo de eso
link = soup.findAll('img')[-1]['src']

urllib.request.urlretrieve('http://www.esrl.noaa.gov'+link, "../Figuras/"+str(ANIO)+"/"+str(MES)+"/NCEP_zg200_Men.png")
# Out:
# 7
# 9
# 2016
# 2016
# ('../Figuras/2016/11/NCEP_zg200_Men.png',
#  <http.client.HTTPMessage at 0x7f8c28517630>)

# %%
#recorto las figuras y las guardo como eps
from PIL import Image    #paquete para trabajar imagenes

# Obs mensual

im = Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/NCEP_zg200_Men.png").convert('RGB').save('new.png')
im = Image.open('new.png')
w, h = im.size
#%lef %uppr %right lower
im.crop((50, 70, w-30, h-25)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/NCEP_zg200_Men.eps","EPS")  

# Obs estacional

im = Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/NCEP_zg200_Est.png").convert('RGB').save('new.png')
im = Image.open('new.png')
w, h = im.size
#%lef %uppr %right lower
im.crop((50, 70, w-30, h-25)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/NCEP_zg200_Est.eps","EPS")

# %%
import urllib.request

# Bajar imagenes de http://www.cpc.ncep.noaa.gov (CFS forecasts) 
# Pronosticos trimestrales previos

if MES>=4:
    mes_I=MES-3
    mes_F=MES-1
    anio_I=ANIO
    anio_F=ANIO
elif MES>=2:
    mes_I=MES-3+12
    mes_F=MES-1
    anio_I=ANIO-1
    anio_F=ANIO
elif MES==1:
    mes_I=MES-3+12
    mes_F=MES-1+12
    anio_I=ANIO-1
    anio_F=ANIO-1
    
print(mes_I)
print(mes_F)
print(anio_I)
print(anio_F)

# Verificacion Pronos estacionales

if mes_I>=10:
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_I)+str(mes_I)+'/imagesInd1/glbz200SeaInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI1.gif")
    
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_I)+str(mes_I)+'/imagesInd2/glbz200SeaInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI2.gif")
    
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_I)+str(mes_I)+'/imagesInd3/glbz200SeaInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI3.gif")
    
elif mes_I<10:
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_I)+str(0)+str(mes_I)+'/imagesInd1/glbz200SeaInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI1.gif")
    
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_I)+str(0)+str(mes_I)+'/imagesInd2/glbz200SeaInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI2.gif")
    
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_I)+str(0)+str(mes_I)+'/imagesInd3/glbz200SeaInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI3.gif")
 
# Verficacion Pronos mensuales

if mes_F>=10:
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_F)+str(mes_F)+'/imagesInd1/glbz200MonInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI1.gif")
    
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_F)+str(mes_F)+'/imagesInd2/glbz200MonInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI2.gif")

    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_F)+str(mes_F)+'/imagesInd3/glbz200MonInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI3.gif")
    
elif mes_F<10:
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_F)+str(0)+str(mes_F)+'/imagesInd1/glbz200MonInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI1.gif")
    
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_F)+str(0)+str(mes_F)+'/imagesInd2/glbz200MonInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI2.gif")
    
    url='http://www.cpc.ncep.noaa.gov/products/people/wwang/cfsv2_fcst_history/'+str(anio_F)+str(0)+str(mes_F)+'/imagesInd3/glbz200MonInd1.gif'
    urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI3.gif")
    
# Proximos Pronos estacionales    

url='http://origin.cpc.ncep.noaa.gov/products/people/wwang/cfsv2fcst/imagesInd1/glbz200SeaInd1.gif'
urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI1.gif")

url='http://origin.cpc.ncep.noaa.gov/products/people/wwang/cfsv2fcst/imagesInd2/glbz200SeaInd1.gif'
urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI2.gif")

url='http://origin.cpc.ncep.noaa.gov/products/people/wwang/cfsv2fcst/imagesInd3/glbz200SeaInd1.gif'
urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI3.gif")
    
# Proximos Pronos estacionales con mascara

url='http://origin.cpc.ncep.noaa.gov/products/people/wwang/cfsv2fcst/imagesInd1/glbz200SeaMaskInd1.gif'
urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI1.gif")

url='http://origin.cpc.ncep.noaa.gov/products/people/wwang/cfsv2fcst/imagesInd2/glbz200SeaMaskInd1.gif'
urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI2.gif")

url='http://origin.cpc.ncep.noaa.gov/products/people/wwang/cfsv2fcst/imagesInd3/glbz200SeaMaskInd1.gif'
urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI3.gif")
# Out:
# 8
# 10
# 2016
# 2016
# ('../Figuras/2016/11/CFS_zg200_Est_PRO_Mask_CI3.gif',
#  <http.client.HTTPMessage at 0x7f8c1b8eb0b8>)

# %%
#abro corto y guardo como eps

from PIL import Image    #paquete para trabajar imagenes

# Verficacion Pronos estacionales

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI1.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI1.eps","EPS")  

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI2.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI2.eps","EPS") 

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI3.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_VER_CI3.eps","EPS") 

# Verficacion Pronos mensuales

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI1.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI1.eps","EPS")  

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI2.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI2.eps","EPS") 

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI3.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Mon_VER_CI3.eps","EPS") 

#pronos estacionales

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI1.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI1.eps","EPS")  

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI2.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI2.eps","EPS")  

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI3.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_CI3.eps","EPS")  


#pronos estacionales con mascara

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI1.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI1.eps","EPS")  

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI2.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI2.eps","EPS")  

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI3.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((60, 120, w-90, h-130)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI3.eps","EPS")

# %%
from PIL import Image    #paquete para trabajar imagenes
# recorto una barra para poner en el ppt
Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/CFS_zg200_Est_PRO_Mask_CI3.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((180, 720, w-180, h)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/barra_CFS.eps","EPS")

# %%
#Pronosticos IRI  FALTA DEJAR GENERICO EL MES Y ANIO
#
import urllib.request
from PIL import Image    #paquete para trabajar imagenes

#Pronosticos PP
url = 'http://iri.columbia.edu/climate/forecast/net_asmt/'+str(ANIO)+'/'+month+str(ANIO)+'/images/'+trimestre1+'17_SAm_pcp.gif'
response = urllib.request.urlopen(url)
urllib.request.urlretrieve(url,'../Figuras/'+str(ANIO)+'/'+str(MES)+'/IRI_'+trimestre1+str(anio_c)+'_SAm_pcp.gif')

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+'/IRI_'+trimestre1+str(anio_c)+'_SAm_pcp.gif').convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/IRI_trim_sig_SAm_pcp.eps",'EPS')

#Pronosticos t2m
url = 'http://iri.columbia.edu/climate/forecast/net_asmt/'+str(ANIO)+'/'+month+str(ANIO)+'/images/'+trimestre1+'17_SAm_temp.gif'
response = urllib.request.urlopen(url)
urllib.request.urlretrieve(url,'../Figuras/'+str(ANIO)+'/'+str(MES)+'/IRI_'+trimestre1+'16_SAm_temp.gif')

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+'/IRI_'+trimestre1+'16_SAm_temp.gif').convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/IRI_trim_sig_SAm_temp.eps",'EPS')


#viejos

#url = 'http://iri.columbia.edu/climate/forecast/net_asmt/2016/jul2016/images/ASO16_SAm_temp.gif'
#response = urllib.request.urlopen(url)
#urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/IRI_ASO16_SAm_temp.gif")

#convierto a eps para usar en latex

#Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/IRI_ASO16_SAm_temp.gif").convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/IRI_ASO16_SAm_temp.eps",'EPS')

# %%
#NMME

import urllib.request
from PIL import Image    #paquete para trabajar imagenes


#Pronostico precipitacion NMME

url = 'http://www.cpc.ncep.noaa.gov/products/international/nmme/probabilistic_seasonal/samerica_nmme_prec_3catprb_NovIC_Dec2016-Feb2017.png'

response = urllib.request.urlopen(url)

urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/NMME_DJF"+str(anio_c)+"_pcp.gif")

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/NMME_DJF"+str(anio_c)+'_pcp.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size
#%lef %uppr %right lower
im.crop((0, 50, w, h)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/NMME_trim_sig_pcp.eps",'EPS')

#Pronostico temperature NMME

url =  "http://www.cpc.ncep.noaa.gov/products/international/nmme/plots_seasonal/samerica_nmme_tmp2m_proban_NovIC_Dec2016-Feb2017.png"

response = urllib.request.urlopen(url)

urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/NMME_DJF"+str(anio_c)+"_temp.gif")

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/NMME_DJF"+str(anio_c)+"_temp.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size

#%lef %uppr %right lower
im.crop((100, 30, w-120, h)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/NMME_trim_sig_temp.eps",'EPS')

# %%
#prono de eurobrisa
import urllib.request
from PIL import Image    #paquete para trabajar imagenes
# el actual

url = "http://img0.cptec.inpe.br/~reuroimg/forecasts/main.png"

response = urllib.request.urlopen(url)

urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/EUROBRISA_DJF"+str(anio_c)+"_pcp.png")

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/EUROBRISA_DJF16_pcp.png").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size

#%lef %uppr %right lower
im.crop((10, 80, w-10, h)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/EUROBRISA_trim_sig_pcp.eps",'EPS')

# %%
#bajo info del SMN
import urllib.request
from PIL import Image    #paquete para trabajar imagenes

#=========================estadistico lluvia 1
url = "http://www.smn.gov.ar/clima/imagenes/prono_est-llu1.gif"

response = urllib.request.urlopen(url)

urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN1_trim_act_pcp.gif")

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN1_trim_act_pcp.gif").convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN1_trim_act_pcp.eps",'EPS')

#=======================estadistico lluvia 2
url = "http://www.smn.gov.ar/clima/imagenes/prono_est-llu2.gif"

response = urllib.request.urlopen(url)

urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN2_trim_act_pcp.gif")

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN2_trim_act_pcp.gif").convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN2_trim_act_pcp.eps",'EPS')

#=========================estadistico temperatura 1
url = "http://www.smn.gov.ar/clima/imagenes/prono_est-tmed1.gif"

response = urllib.request.urlopen(url)

urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN1_trim_act_temp.gif")

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN1_trim_act_temp.gif").convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN1_trim_act_temp.eps",'EPS')

#=========================estadistico temperatura 2
url = "http://www.smn.gov.ar/clima/imagenes/prono_est-tmed2.gif"

response = urllib.request.urlopen(url)

urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN2_trim_act_temp.gif")

#convierto a eps para usar en latex

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN2_trim_act_temp.gif").convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/SMN2_trim_act_temp.eps",'EPS')

#bajo observaciones que no me mandaron

#url = "http://www.smn.gov.ar/hidro/imagenes/allu3m.gif"

#urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/obs_prec.gif")

#convierto a eps para usar en latex

#Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/obs_prec.gif").convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/obs_prec.eps",'EPS')

#url = "http://www.smn.gov.ar/clima/imagenes/atmed3.gif"

#urllib.request.urlretrieve(url,"../Figuras/"+str(ANIO)+"/"+str(MES)+"/obs_temp.gif")

#convierto a eps para usar en latex

#Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/obs_temp.gif").convert('RGB').save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/obs_temp.eps",'EPS')

# %%
#en este bloque deberiamos poner el proceso de descarga del archivo en WMO

#el dominio que hay que seleccionar es el siguiente: 275-330  60S - 15N

#lo que voy a dejar planteado ahora es recortar la figura que tiene como nombre WMO_SON16_pcp.gif idem la de temp

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/WMO_DJF"+str(anio_c)+"_pcp.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size

#%lef %uppr %right lower
im.crop((210, 80, w-230, h-70)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/WMO_trim_sig_pcp.eps",'EPS')

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/WMO_DJF"+str(anio_c)+"_temp.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size

#%lef %uppr %right lower
im.crop((210, 80, w-230, h-70)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/WMO_trim_sig_temp.eps",'EPS')

#corto las barras de colores

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/WMO_DJF"+str(anio_c)+"_pcp.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size

#%lef %uppr %right lower
im.crop((5, 530, w-100, h)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/barra_pcp.eps",'EPS')

Image.open("../Figuras/"+str(ANIO)+"/"+str(MES)+"/WMO_DJF"+str(anio_c)+"_temp.gif").convert('RGB').save('new.jpeg')
im = Image.open('new.jpeg')
w, h = im.size

#%lef %uppr %right lower
im.crop((5, 530, w-100, h)).save("../Figuras/"+str(ANIO)+"/"+str(MES)+"/barra_temp.eps",'EPS')
